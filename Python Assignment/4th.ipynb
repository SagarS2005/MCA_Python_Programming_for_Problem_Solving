# %%
lst=[]
# print("Enter List Element:")
for i in range(5):
    lst.insert(i,int(input(f"enter {i+1} st element ")))

print(lst)
num=int(input("Enter element to find:"))
count=0; found=True
for _ in range(5):
    if lst[_]==num:
        index=_
    # else:
    #     count+=1

if found==False:
    print("Element is not present into list")
else:
    print(f"element {num} at position:",index+1)
# Out:
# [4, 5, 7, 2, 9]
# element 5 at position: 2
