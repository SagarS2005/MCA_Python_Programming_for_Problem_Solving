# %%
employees = [
    {"name": "Anuj", "salary": 25000},
    {"name": "Ritik", "salary": 15000},
    {"name": "Piyush", "salary": 29000},
    {"name": "Ankit", "salary": 95000}
]

sorted_emps = sorted(employees, key=lambda x: x["salary"])
print(sorted_emps)
# Out:
# [{'name': 'Ritik', 'salary': 15000}, {'name': 'Anuj', 'salary': 25000}, {'name': 'Piyush', 'salary': 29000}, {'name': 'Ankit', 'salary': 95000}]
