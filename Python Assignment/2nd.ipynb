# %%
number=int(input("Enter the number of coin : "))
print("Enter the number of coin:",number)
        # for atleast one
numOfFavourableOutcome=1        #probability of not getting head
sampleSpace=number**2       #samplespace=total number of possible outcome
if number==1:
    sampleSpace=2
      
#for the coin there are only 2 possible outcomes (head and tail)
num_of_event=numOfFavourableOutcome/sampleSpace     #subset of sample space

probability=1-num_of_event         # probability of getting head
print("Probability of Getting heaed:" ,probability)
# Out:
# Probability of Getting heaed: 0.75
