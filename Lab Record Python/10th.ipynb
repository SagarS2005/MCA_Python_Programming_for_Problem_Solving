# %% [markdown]
# Squre Root

# %%
import  math
num=int(input("Enter number:"))
print("Square Root of number:",num,"is:",math.sqrt(num))
# Out:
# Square Root of number: 2 is: 1.4142135623730951

# %% [markdown]
# for factorial

# %%
import math
num=int(input("Enter number for factorial:"))

print("Factorial of number:",num,"is:",math.factorial(num))
# Out:
# Factorial of number: 2 is: 2

# %% [markdown]
# Power function

# %%
import  math
num=int(input("Enter number:"))
pow=int(input("Enter power:;"))
print("Power number",num,"is:",math.pow(num,pow))
# Out:
# Power number 4 is: 4096.0
