# %%
n = int(input("How many elements? "))

items = []
for _ in range(n):
    items.append(int(input("Enter element: ")))

print("Original List:", items)
# remove duplicates manually
unique = []
for x in items:
    if x not in unique:
        unique.append(x)



print("Sorted unique list:", unique)
# Out:
# Original List: [2, 3, 5, 7, 3, 5]
# Sorted unique list: [2, 3, 5, 7]
