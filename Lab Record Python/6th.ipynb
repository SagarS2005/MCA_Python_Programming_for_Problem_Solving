# %%
num=int(input("Enter Number:"))
print("Enter Number:",num)
print("binary:",bin(num))
print("Octal:",oct(num))
print("Hexadecimal:",hex(num))
# Out:
# Enter Number: 23
# binary: 0b10111
# Octal: 0o27
# Hexadecimal: 0x17
