# %%
import random
import string

lower=string.ascii_lowercase
upper=string.ascii_uppercase
digit=string.digits
special = "!@#$*"
password=[]
password1=''
char=lower+upper+digit+special
for _ in range(0,13):
    # password.append(random.choice(char))
    password1+=random.choice(char)

# finalPassword=''.join(password)

# print(finalPassword.title())
print(password1)

if password1[0] != string.digits:
    print(password1.title())
# Out:
# mMVZ159K6BTI!
# Mmvz159K6Bti!
