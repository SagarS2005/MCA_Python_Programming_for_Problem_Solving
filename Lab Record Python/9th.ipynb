# %%
import csv

department_salaries = {}

with open("employees.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        dept = row["department"]
        salary = float(row["salary"])
        
        if dept not in department_salaries:
            department_salaries[dept] = []
        department_salaries[dept].append(salary)

# calculate and display average
for dept, salaries in department_salaries.items():
    avg_salary = sum(salaries) / len(salaries)
    print(f" department:{dept}: \t Avereage Salary{avg_salary:.2f}")
# Out:
#  department:IT: 	 Avereage Salary52500.00
#  department:HR: 	 Avereage Salary50000.00
