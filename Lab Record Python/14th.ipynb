# %%
from Shapes import circle
from Shapes import rectangle

# %% [markdown]
# # 1. Area and Perimeter Of rectangle

# %%
print("Area of Circle for radius 5 :",circle.areaOfCircle(5))
print("Perimeter of Circle for radius 5 :",circle.perimeterOfCircle(5))
# Out:
# Area of Circle for radius 5 : 78.53981633974483
# Perimeter of Circle for radius 5 : 31.41592653589793

# %% [markdown]
# # 2. Area and Perimeter of Rectangle

# %%
print("Area of Rectangle for length 5 and width 4:",rectangle.areaOfReactangle(5,4))
print("Perimeter of Rectangle 5 and width 4 :",rectangle.perimeterOfRectangle(5,4))
# Out:
# Area of Rectangle for length 5 and width 4: 20
# Perimeter of Rectangle 5 and width 4 : 18
