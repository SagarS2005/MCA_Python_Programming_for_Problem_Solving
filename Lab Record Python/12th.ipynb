# %%
import random
students=['sagar','roshni','pushpanjali','shubham','vijay','abhi']
print("CR: ",random.choice(students))
random.shuffle(students)
print(students)
# Out:
# CR:  pushpanjali
# ['shubham', 'pushpanjali', 'abhi', 'roshni', 'vijay', 'sagar']
